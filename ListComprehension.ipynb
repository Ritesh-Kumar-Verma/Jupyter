# %%
first_names = ['Jane', 'John', 'Mary']
last_names = ['Doe', 'Smith', 'Johnson']

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %%
[ ar[1] for ar in matrix]
# Out:
# [2, 5, 8]

# %%
[x[0]+" "+ x[1] for x in zip(first_names,last_names)]
# Out:
# ['Jane Doe', 'John Smith', 'Mary Johnson']

# %%
ranks = ['J', 'Q', 'K']
suits = ['Hearts', 'Spades']

# %%
[(i,j) for i in ranks for j in suits]
# Out:
# [('J', 'Hearts'), ('J', 'Spades'), ('Q', 'Hearts'), ('Q', 'Spades'), ('K', 'Hearts'), ('K', 'Spades')]

# %%
files = ['script.py', 'image.png', 'data.txt', 'main.py', 'styles.css']

# %%
[x for x in files if x[-1:-4:-1] == 'yp.']
# Out:
# ['script.py', 'main.py']

# %%
[[0 for x in range(3)] for y in range(3)]
# Out:
# [[0, 0, 0], [0, 0, 0], [0, 0, 0]]

# %%
matrix = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %%
[list(x) for x in zip(matrix[0],matrix[1],matrix[2])]
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
[[row[i] for row in matrix] for i in range(3)]
# Out:
# [[1, 4, 7], [2, 5, 8], [3, 6, 9]]

# %%
[x for ar in matrix for x in ar if x%2 == 0]
# Out:
# [2, 4, 6, 8]
