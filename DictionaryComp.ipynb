# %%
fruits = ['apple', 'banana', 'kiwi', 'mango']

# %%
{x : len(x) for x in fruits}
# Out:
# {'apple': 5, 'banana': 6, 'kiwi': 4, 'mango': 5}

# %%
inventory = [('apples', 15), ('bananas', 4), ('oranges', 20), ('kiwis', 2)]

# %%
{x:y for x, y in inventory if y<5}
# Out:
# {'bananas': 4, 'kiwis': 2}

# %%
id_to_name = {101: 'Alice', 102: 'Bob', 103: 'Charlie'}

# %%
{x:y for x,y in id_to_name.items()}
# Out:
# {101: 'Alice', 102: 'Bob', 103: 'Charlie'}

# %%
scores = {'Alice': 85, 'Bob': 59, 'Charlie': 92, 'David': 73}

# %%
{name: "Pass" if score>=60 else "Fail" for name, score in scores.items()}
# Out:
# {'Alice': 'Pass', 'Bob': 'Fail', 'Charlie': 'Pass', 'David': 'Pass'}

# %%
inventory = {'apple': 30, 'banana': 0, 'orange': 15, 'kiwi': 0, 'apricot': 0}

# %%
{name :("In Stock" if quantity>0 else "Out of Stock") for name, quantity in inventory.items() if name[0:1] in ["a","e","i","o","u"]}
# Out:
# {'apple': 'In Stock', 'orange': 'In Stock', 'apricot': 'Out of Stock'}
