# %%
import numpy as np

# %%
array = np.array([1,2,3,4])
print(array)                                #[1 2 3 4]
# Out:
# [1 2 3 4]

# %%
array = array*2                             #array = array*2
print(array)
# Out:
# [2 4 6 8]
