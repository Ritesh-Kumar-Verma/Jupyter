# %%
#String methods return new String

# %%
t1 = "apple, banana, orange"
fruit_list = t1.split(", ")   #['apple', 'banana', 'orange']
t2 = " & ".join(fruit_list)   #'apple & banana & orange'
# Out:
# 'apple & banana & orange'

# %%
t3 = "   hello    "
clean = t3.strip() #'hello'
# Out:
# 'hello'

# %%
sentence = "I like cats. Cats are great."
print(sentence.count('a'))           #4
newSentence = sentence.replace("cats","dogs")      #'I like dogs. Cats are great.'      sentence.replace donot edit original string
print(newSentence.count('a'))           #3
# Out:
# 4
# 3

# %%
t4 = "hello"
t4 = t4.upper()
t4                      #'HELLO'

t4 = t4.lower()
t4                      #'hello'


print("my name is ritesh".title())             #'My Name Is Ritesh'    make first letter of every word capital

print("my name is ritesh".capitalize())         #'My name is ritesh'    make only first letter of string capital
# Out:
# My Name Is Ritesh
# My name is ritesh

# %%
filename = "script.py"
print(filename.endswith(".py")) # Output: True

age = "25"
print(age.isdigit())            # Output: True

# %%
t5 = " \n asdasda \n   "
print(t5.strip().capitalize())
# Out:
# Asdasda

# %%
text = "mississippi"
result = text.replace("s", "z", 2)

print(result)
# Out:
# mizzissippi
