# %%
s="hello"
k=2

# %%
from itertools import permutations

# %%
x = list(permutations(s,k))
x
# Out:
# [('h', 'e'),
#  ('h', 'l'),
#  ('h', 'l'),
#  ('h', 'o'),
#  ('e', 'h'),
#  ('e', 'l'),
#  ('e', 'l'),
#  ('e', 'o'),
#  ('l', 'h'),
#  ('l', 'e'),
#  ('l', 'l'),
#  ('l', 'o'),
#  ('l', 'h'),
#  ('l', 'e'),
#  ('l', 'l'),
#  ('l', 'o'),
#  ('o', 'h'),
#  ('o', 'e'),
#  ('o', 'l'),
#  ('o', 'l')]

# %%
kl=list(permutations(s,1))
for i in kl:
    print(i)
    # print("".join(i))
# Out:
# ('h',)
# ('e',)
# ('l',)
# ('l',)
# ('o',)
