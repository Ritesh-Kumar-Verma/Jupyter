# %%
import numpy as np
from PIL import Image

# %%
img=Image.open("scan0004.jpg")

# %%
img_array = np.array(img)
img_array
# Out:
# array([[[251, 255, 254],
#         [250, 250, 250],
#         [249, 243, 243],
#         ...,
#         [254, 254, 255],
#         [255, 250, 254],
#         [255, 250, 254]],
#
#        [[252, 255, 255],
#         [252, 252, 252],
#         [249, 243, 245],
#         ...,
#         [255, 254, 255],
#         [255, 250, 254],
#         [255, 250, 254]],
#
#        [[254, 255, 255],
#         [254, 254, 254],
#         [248, 242, 244],
#         ...,
#         [255, 253, 254],
#         [255, 250, 254],
#         [255, 250, 254]],
#
#        ...,
#
#        [[244, 250, 248],
#         [239, 245, 243],
#         [233, 237, 238],
#         ...,
#         [230, 236, 252],
#         [231, 234, 253],
#         [231, 234, 253]],
#
#        [[243, 247, 248],
#         [240, 244, 245],
#         [236, 237, 241],
#         ...,
#         [230, 236, 252],
#         [230, 235, 254],
#         [230, 235, 254]],
#
#        [[246, 250, 251],
#         [244, 248, 249],
#         [238, 239, 244],
# ...
